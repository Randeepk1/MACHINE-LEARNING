# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
data = pd.read_csv("/content/driver-data.csv")

X= data.iloc[0:4000].values
X.shape

cluster1 = []
for i in range(1,10):
  k = KMeans(n_clusters = i)
  k.fit(x)
  cluster1.append(k.inertia_)
cluster1
plt.scatter(range(1,10),cluster1)
plt.show()

kms = KMeans(n_clusters=4,max_iter=1000)
kfit1 = kms.fit(x)
pred = kfit1.predict(x)
pred

k = 3
n = X.shape[0]
c = X.shape[1]

mean = np.mean(X, axis = 0)
std = np.std(X, axis = 0)
centers = np.random.randn(k,c)*std + mean

colors=['yellow', 'green', 'red']
for i in range(n):
    plt.scatter(X[i, 0], X[i,1], s=7)
plt.scatter(centers[:,0], centers[:,1], marker='*', c='r', s=150)


kms = KMeans(n_clusters=3,max_iter=1000)
kfit1 = kms.fit(x)
pred = kfit1.predict(x)
pred

plt.scatter(X[kms.predict(X)==0,0],X[kms.predict(X) ==0,1],s = 100, c = 'red')
plt.scatter(X[kms.predict(X)==1,0],X[kms.predict(X) ==1,1],s = 100, c = 'blue')
plt.scatter(X[kms.predict(X)==2,0],X[kms.predict(X) ==2,1],s = 100, c = 'orange')
plt.scatter(X[kms.predict(X)==3,0],X[kms.predict(X) ==3,1],s = 100, c = 'yellow')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4000 non-null   int64
#  1   mean_dist_day         4000 non-null   float64
#  2   mean_over_speed_perc  4000 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 93.9 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4000 non-null   int64
#  1   mean_dist_day         4000 non-null   float64
#  2   mean_over_speed_perc  4000 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 93.9 KB
