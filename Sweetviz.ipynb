# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
# !pip install sweetviz

# %%
data = pd.read_csv("/content/creditcard.csv")
data
# Out:
#         Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0          0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1          0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2          1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3          1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4          2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
# ...      ...       ...       ...       ...  ...       ...       ...     ...    ...
# 29794  35633  0.786689 -0.691214 -0.329291  ... -0.001435  0.025559  200.00    0.0
# 29795  35633  0.800996 -2.159993  0.008378  ... -0.024151  0.077021  363.00    0.0
# 29796  35633  1.115726 -0.472602  0.983034  ... -0.060566  0.003541   36.92    0.0
# 29797  35634  1.239103 -1.000617  0.843324  ...  0.036574  0.035202   91.00    0.0
# 29798  35634  1.374193 -0.720679  0.891375  ...       NaN       NaN     NaN    NaN
#
# [29799 rows x 31 columns]

# %%
report = sv.analyze(data)
# Out:
# :FEATURES DONE:                    |█████████████████████| [100%]   00:18  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:01  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.
