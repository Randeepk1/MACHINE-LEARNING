# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.impute import MissingIndicator
from scipy.stats import iqr

# %%
data = pd.read_csv("/content/train.csv")

# %%
data.isnull().sum().sum()
# Out:
# 6965

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Length: 1460, dtype: bool

# %%
data['PoolQC'].isnull().sum()
# Out:
# 1453

# %%
data['LotFrontage'].isnull().sum().sum()
# Out:
# 259

# %%
data['FireplaceQu'].isnull().sum().sum()
# Out:
# 690

# %%
(data.dtypes[data.dtypes!='object'])
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
(data.dtypes[data.dtypes=='object'])
# Out:
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# ...

# %%
(data.dtypes[data.dtypes=='object']).index
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
data.drop(['Alley','PoolQC'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 79 columns]

# %%
data.isnull().sum().sum()
# Out:
# 4143

# %%
data.isna().sum().sum()
# Out:
# 4143

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
type(data['GarageType'].isnull().sum())
# Out:
# numpy.int64

# %%
data['GarageType'].isnull().sum()
# Out:
# 81

# %%
data.fillna(data['GarageType'].mode()[0])
# Out:
#         Id  MSSubClass MSZoning  ... SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...       WD         Normal    208500
# 1        2          20       RL  ...       WD         Normal    181500
# 2        3          60       RL  ...       WD         Normal    223500
# 3        4          70       RL  ...       WD        Abnorml    140000
# 4        5          60       RL  ...       WD         Normal    250000
# ...    ...         ...      ...  ...      ...            ...       ...
# 1455  1456          60       RL  ...       WD         Normal    175000
# 1456  1457          20       RL  ...       WD         Normal    210000
# 1457  1458          70       RL  ...       WD         Normal    266500
# 1458  1459          20       RL  ...       WD         Normal    142125
# 1459  1460          20       RL  ...       WD         Normal    147500
#
# [1460 rows x 79 columns]

# %%
type(data['GarageType'].isnull().sum())
# Out:
# numpy.int64

# %%
data['GarageType'].isnull().sum()
# Out:
# 81

# %%
data.isnull().sum().sum()
# Out:
# 4143

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# missing_values = ['?',"--"]
# data.fillna(data.mean(),inplace=True)

# %%
# data = data.GarageType.fillna(data.GarageType.mode[0],inplace = True),

# %%
data['GarageType'].astype(object)
# Out:
# 0       Attchd
# 1       Attchd
# 2       Attchd
# 3       Detchd
# 4       Attchd
#          ...
# 1455    Attchd
# 1456    Attchd
# 1457    Attchd
# 1458    Attchd
# 1459    Attchd
# Name: GarageType, Length: 1460, dtype: object

# %%
data['GarageType'].isin(['attchd']).sum()
# Out:
# 0

# %%
data['GarageType'].isna().sum()
# Out:
# 81

# %%
data['GarageType'].mode()[0]
# Out:
# 'Attchd'

# %%
obcols = (data.dtypes[data.dtypes=='object'])
obcols
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# Fence            object
# ...

# %%
data.isnull().sum().sum()
# Out:
# 4143

# %%
data.fillna({'MiscFeature':data['MiscFeature'].mode()[0]},inplace=True)

# %%
data.fillna({'GarageType':data['GarageType'].mode()[0]},inplace=True)

# %%
data['GarageType'].isna().sum()
# Out:
# 0

# %%
data['GarageCond'].isna().sum()
# Out:
# 81

# %%
data['MasVnrType'] .isna().sum()
# Out:
# 8

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df_most_common_imputed = data.apply(lambda x: x.fillna(x.value_counts().mode()[0]),axis=1)
df_most_common_imputed
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 79 columns]

# %%
df_most_common_imputed = data.apply(lambda x: x.fillna(x.mode()[0]),axis=1)
df_most_common_imputed
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py:921: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   warn(f"Unable to sort modes: {err}")
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py:921: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   warn(f"Unable to sort modes: {err}")
#         Id  MSSubClass MSZoning  ... SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...       WD         Normal    208500
# 1        2          20       RL  ...       WD         Normal    181500
# 2        3          60       RL  ...       WD         Normal    223500
# 3        4          70       RL  ...       WD        Abnorml    140000
# 4        5          60       RL  ...       WD         Normal    250000
# ...    ...         ...      ...  ...      ...            ...       ...
# 1455  1456          60       RL  ...       WD         Normal    175000
# ...

# %%
from sklearn_pandas import CategoricalImputer

# %%
imputer = CategoricalImputer()
imputer.fit_transform(obcols)
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O')], dtype=object)

# %%
numeric = (data.dtypes[data.dtypes!='object'])

# %%
imputer = CategoricalImputer()
imputer.fit_transform(numeric)
# Out:
# array([dtype('int64'), dtype('int64'), dtype('float64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('float64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('float64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('int64')], dtype=object)

# %%
data.apply(lambda x:x.fillna(x.value_counts().index[0]))
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 79 columns]

# %%
data.isnull().sum().sum()
# Out:
# 2656

# %%
data.apply(lambda x:x.fillna(x.value_counts().mode()[0]))
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 79 columns]

# %%
data.apply(lambda x:x.fillna(x.value_counts().mean()))
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 79 columns]

# %%
data.isnull().sum().sum()
# Out:
# 2656

# %%
data.apply(lambda x: pd.to_numeric(x, errors='coerce').notnull().all())
# Out:
# Id                True
# MSSubClass        True
# MSZoning         False
# LotFrontage      False
# LotArea           True
#                  ...
# MoSold            True
# YrSold            True
# SaleType         False
# SaleCondition    False
# SalePrice         True
# Length: 79, dtype: bool

# %%
data.apply(lambda x: 'RL' if 'RL' in x else x)
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 79 columns]

# %%
data['MSZoning'].apply(lambda x: 'RL' if 'RL' in x else x)
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
data['LotShape'].apply(lambda x: 'RL' if 'RL' in x else x)
# Out:
# 0       Reg
# 1       Reg
# 2       IR1
# 3       IR1
# 4       IR1
#        ...
# 1455    Reg
# 1456    Reg
# 1457    Reg
# 1458    Reg
# 1459    Reg
# Name: LotShape, Length: 1460, dtype: object

# %%
data['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
data['MSZoning'].str.replace(',', '')
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %%
data.isnull().values.any()
# Out:
# True

# %%
np.where(data.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
data['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
data.BsmtQual.astype(str)
# Out:
# 0       Gd
# 1       Gd
# 2       Gd
# 3       TA
# 4       Gd
#         ..
# 1455    Gd
# 1456    Gd
# 1457    TA
# 1458    TA
# 1459    TA
# Name: BsmtQual, Length: 1460, dtype: object

# %%
data.BsmtQual.isnull().sum().sum()
# Out:
# 37

# %%
data.Fence .isnull().sum().sum()
# Out:
# 1179

# %%
data.fillna({'BsmtQual':data['BsmtQual'].mode()[0]},inplace=True)

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
data[data == ''].index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
data[ (data.notnull()) & (data !=u'') ].index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
data.fillna(data.median(),inplace=True)

# %%
data.fillna(data.mean(),inplace=True)

# %%
# data[data['GarageQual'].apply(lambda x:x.isspace() == False)].sum()

# %%
data.drop(['Condition1','Condition2','BldgType','HouseStyle','RoofMatl','Exterior1st'], axis = 1,inplace=True)

# %%
data.corr()
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.009921  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.356718  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.009921   -0.356718     1.000000  ...  0.010451  0.006380   0.334771
# LotArea       -0.033226   -0.139781     0.304522  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.234812  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.053281  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.116685  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.083348  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.051071    0.023573     0.178469  ... -0.006723 -0.008317   0.472614
# BsmtFinSF1    -0.005024   -0.069836     0.214367  ... -0.015727  0.014359   0.386420
# ...

# %%
data.drop('Street',inplace=True,axis=1)

# %%
data.drop('MSZoning',inplace=True,axis=1)

# %%
data.isnull().sum().sum()
# Out:
# 2271

# %%
col = [col for col in data.SaleType if  'WDWDNEW' in col]
data = data.drop(col,1)
data['SaleType'].isnull().sum()
# Out:
# 0

# %%
data['SaleType'].isnull().sum()
# Out:
# 0

# %%
# data[data['BldgType'].apply(lambda x:x.isspace() == False)].index

# %%
type(numeric)
# Out:
# pandas.core.series.Series

# %%
obcols.fillna(obcols.mode()[0],inplace=True)

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
data['BsmtQual'].isnull().sum()
# Out:
# 0

# %%
data['BsmtQual'].isnull().sum()
# Out:
# 0

# %%
data.BsmtHalfBath.dtypes
# Out:
# dtype('int64')

# %%
# data['MSZoning'].isnull().sum()

# %%
data.shape
# Out:
# (1460, 71)

# %%
float_column = data.dtypes[data.dtypes=='float64'].index
for x in float_column:
  plt.figure()
  data.boxplot([x])

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['LotFrontage'][data['LotFrontage']<UT]=outlier
data.boxplot('LotFrontage')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
int_column = data.dtypes[data.dtypes=='int64'].index
for x in int_column:
  plt.figure()
  data.boxplot([x])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['SalePrice'][data['SalePrice']>UT]=outlier
data.boxplot('SalePrice')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['WoodDeckSF'][data['WoodDeckSF']>UT]=outlier
data.boxplot('WoodDeckSF','ScreenPorch')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
# ...

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['SalePrice'][data['SalePrice']>UT]=outlier
data.boxplot('SalePrice')

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['OpenPorchSF'][data['OpenPorchSF']<UT]=outlier
data.boxplot('OpenPorchSF')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['SalePrice'][data['SalePrice']>UT]=outlier
data.boxplot('SalePrice')

# %%
object_column = data.dtypes[data.dtypes=='object'].index
for x in float_column:
  plt.figure()
  data.boxplot([x])

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['EnclosedPorch'][data['EnclosedPorch']<UT]=outlier
data.boxplot('EnclosedPorch')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['LotFrontage'][data['LotFrontage']<UT]=outlier
data.boxplot('LotFrontage')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
# ...

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['PoolArea'][data['PoolArea']<UT]=outlier
data.boxplot('PoolArea')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
UT=data[x]. quantile (.75)+iqr(data[x])*1.5
LT=data[x]. quantile (.25)-iqr(data[x])*1.5
outlier = data[x].clip(lower = LT,upper =UT)
data['MasVnrArea'][data['MasVnrArea']<UT]=outlier
data.boxplot('MasVnrArea')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data['MasVnrArea'].isna().sum()
# Out:
# 0

# %%
data['MasVnrType']
# Out:
# 0       BrkFace
# 1          None
# 2       BrkFace
# 3          None
# 4       BrkFace
#          ...
# 1455       None
# 1456      Stone
# 1457       None
# 1458       None
# 1459       None
# Name: MasVnrType, Length: 1460, dtype: object

# %%
data.isnull().sum().sum()
# Out:
# 2271

# %%
obcols.isnull().sum().sum()
# Out:
# 0

# %%
numeric.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
data.drop('Fence',axis=1,inplace=True)

# %%
data.FireplaceQu.isnull().sum().sum()
# Out:
# 690

# %%
data.drop('FireplaceQu',inplace=True,axis=1)

# %%
data['GarageCond'].isna().sum()
# Out:
# 0

# %%
data.GarageCond.dtypes
# Out:
# dtype('O')

# %%
data.fillna(data['GarageCond'].mode()[0],inplace=True)
